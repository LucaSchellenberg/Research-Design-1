# %% [markdown]
# This cell installs all of the Python packages we need:
#
# Pins NumPy to a version <1.23 so that the FAD library’s old import of numpy.dtypes will still work.
#
# Installs JAX/jaxlib (required by FAD under the hood).
#
# Installs the PESQ, SRMR, and Fréchet Audio Distance libraries, plus librosa, soundfile, and scipy for audio I/O and processing.
#
# Installs mir_eval for computing SDR.

# %%
# ─── Cell 1: Install dependencies ───
# !pip install "numpy<1.23"
# !pip install --upgrade jax jaxlib -f https://storage.googleapis.com/jax-releases/jax_releases.html
# !pip install pesq
# !pip install git+https://github.com/jfsantos/SRMRpy.git
# !pip install frechet_audio_distance
# !pip install librosa soundfile scipy
# !pip install mir_eval
# Out:
# Collecting numpy<1.23
#   Using cached numpy-1.22.4-cp311-cp311-linux_x86_64.whl
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.4
#     Uninstalling numpy-1.23.4:
#       Successfully uninstalled numpy-1.23.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jax 0.6.1 requires numpy>=1.25, but you have numpy 1.22.4 which is incompatible.
# jax 0.6.1 requires scipy>=1.11.1, but you have scipy 1.10.1 which is incompatible.
# jaxlib 0.6.1 requires numpy>=1.25, but you have numpy 1.22.4 which is incompatible.
# jaxlib 0.6.1 requires scipy>=1.11.1, but you have scipy 1.10.1 which is incompatible.
# ml-dtypes 0.5.1 requires numpy>=1.23.3; python_version >= "3.11", but you have numpy 1.22.4 which is incompatible.
# frechet-audio-distance 0.3.1 requires numpy==1.23.4, but you have numpy 1.22.4 which is incompatible.
# astropy 7.1.0 requires numpy>=1.23.2, but you have numpy 1.22.4 which is incompatible.
# pymc 5.23.0 requires numpy>=1.25.0, but you have numpy 1.22.4 which is incompatible.
# contourpy 1.3.2 requires numpy>=1.23, but you have numpy 1.22.4 which is incompatible.
# flax 0.10.6 requires numpy>=1.23.2; python_version >= "3.11", but you have numpy 1.22.4 which is incompatible.
# albucore 0.0.24 requires numpy>=1.24.4, but you have numpy 1.22.4 which is incompatible.
# ucxx-cu12 0.42.0 requires numpy<3.0a0,>=1.23, but you have numpy 1.22.4 which is incompatible.
# mizani 0.13.5 requires numpy>=1.23.5, but you have numpy 1.22.4 which is incompatible.
# dask-cudf-cu12 25.2.2 requires numpy<3.0a0,>=1.23, but you have numpy 1.22.4 which is incompatible.
# dm-tree 0.1.9 requires numpy>=1.23.3; python_version >= "3.11", but you have numpy 1.22.4 which is incompatible.
# cuvs-cu12 25.2.1 requires numpy<3.0a0,>=1.23, but you have numpy 1.22.4 which is incompatible.
# pywavelets 1.8.0 requires numpy<3,>=1.23, but you have numpy 1.22.4 which is incompatible.
# numexpr 2.10.2 requires numpy>=1.23.0, but you have numpy 1.22.4 which is incompatible.
# xarray-einstats 0.9.0 requires numpy>=1.25, but you have numpy 1.22.4 which is incompatible.
# xarray-einstats 0.9.0 requires scipy>=1.11, but you have scipy 1.10.1 which is incompatible.
# cvxpy 1.6.5 requires scipy>=1.11.0, but you have scipy 1.10.1 which is incompatible.
# pandas-stubs 2.2.2.240909 requires numpy>=1.23.5, but you have numpy 1.22.4 which is incompatible.
# ucx-py-cu12 0.42.0 requires numpy<3.0a0,>=1.23, but you have numpy 1.22.4 which is incompatible.
# treescope 0.1.9 requires numpy>=1.25.2, but you have numpy 1.22.4 which is incompatible.
# cuml-cu12 25.2.1 requires numpy<3.0a0,>=1.23, but you have numpy 1.22.4 which is incompatible.
# cudf-cu12 25.2.1 requires numpy<3.0a0,>=1.23, but you have numpy 1.22.4 which is incompatible.
# arviz 0.21.0 requires numpy>=1.23.0, but you have numpy 1.22.4 which is incompatible.
# imbalanced-learn 0.13.0 requires numpy<3,>=1.24.3, but you have numpy 1.22.4 which is incompatible.
# bigframes 2.5.0 requires numpy>=1.24.0, but you have numpy 1.22.4 which is incompatible.
# sentence-transformers 4.1.0 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.30.2 which is incompatible.
# matplotlib 3.10.0 requires numpy>=1.23, but you have numpy 1.22.4 which is incompatible.
# pylibraft-cu12 25.2.0 requires numpy<3.0a0,>=1.23, but you have numpy 1.22.4 which is incompatible.
# opencv-python-headless 4.11.0.86 requires numpy>=1.23.5; python_version >= "3.11", but you have numpy 1.22.4 which is incompatible.
# rmm-cu12 25.2.0 requires numpy<3.0a0,>=1.23, but you have numpy 1.22.4 which is incompatible.
# opencv-contrib-python 4.11.0.86 requires numpy>=1.23.5; python_version >= "3.11", but you have numpy 1.22.4 which is incompatible.
# nx-cugraph-cu12 25.2.0 requires numpy<3.0a0,>=1.23, but you have numpy 1.22.4 which is incompatible.
# plotnine 0.14.5 requires numpy>=1.23.5, but you have numpy 1.22.4 which is incompatible.
# albumentations 2.0.8 requires numpy>=1.24.4, but you have numpy 1.22.4 which is incompatible.
# pandas 2.2.2 requires numpy>=1.23.2; python_version == "3.11", but you have numpy 1.22.4 which is incompatible.
# tensorflow 2.18.0 requires ml-dtypes<0.5.0,>=0.4.0, but you have ml-dtypes 0.5.1 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 1.22.4 which is incompatible.
# xarray 2025.3.1 requires numpy>=1.24, but you have numpy 1.22.4 which is incompatible.
# blosc2 3.3.4 requires numpy>=1.26, but you have numpy 1.22.4 which is incompatible.
# opencv-python 4.11.0.86 requires numpy>=1.23.5; python_version >= "3.11", but you have numpy 1.22.4 which is incompatible.
# scikit-image 0.25.2 requires numpy>=1.24, but you have numpy 1.22.4 which is incompatible.
# scikit-image 0.25.2 requires scipy>=1.11.4, but you have scipy 1.10.1 which is incompatible.
# dask-cuda 25.2.0 requires numpy<3.0a0,>=1.23, but you have numpy 1.22.4 which is incompatible.
# pylibcugraph-cu12 25.2.0 requires numpy<3.0a0,>=1.23, but you have numpy 1.22.4 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.22.4 which is incompatible.
# db-dtypes 1.4.3 requires numpy>=1.24.0, but you have numpy 1.22.4 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.10.1 which is incompatible.
# chex 0.1.89 requires numpy>=1.24.1, but you have numpy 1.22.4 which is incompatible.
# Successfully installed numpy-1.22.4
# Looking in links: https://storage.googleapis.com/jax-releases/jax_releases.html
# Requirement already satisfied: jax in /usr/local/lib/python3.11/dist-packages (0.6.1)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.11/dist-packages (0.6.1)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from jax) (0.5.1)
# Collecting numpy>=1.25 (from jax)
#   Using cached numpy-2.3.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.11/dist-packages (from jax) (3.4.0)
# Collecting scipy>=1.11.1 (from jax)
#   Using cached scipy-1.15.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numpy-2.3.0-cp311-cp311-manylinux_2_28_x86_64.whl (16.9 MB)
# Using cached scipy-1.15.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.7 MB)
# Installing collected packages: numpy, scipy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.10.1
#     Uninstalling scipy-1.10.1:
#       Successfully uninstalled scipy-1.10.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# frechet-audio-distance 0.3.1 requires numpy==1.23.4, but you have numpy 2.3.0 which is incompatible.
# frechet-audio-distance 0.3.1 requires scipy==1.10.1, but you have scipy 1.15.3 which is incompatible.
# cupy-cuda12x 13.3.0 requires numpy<2.3,>=1.22, but you have numpy 2.3.0 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.3.0 which is incompatible.
# sentence-transformers 4.1.0 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.30.2 which is incompatible.
# tensorflow 2.18.0 requires ml-dtypes<0.5.0,>=0.4.0, but you have ml-dtypes 0.5.1 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.3.0 which is incompatible.
# Successfully installed numpy-2.3.0 scipy-1.15.3
# Requirement already satisfied: pesq in /usr/local/lib/python3.11/dist-packages (0.0.4)
# Collecting git+https://github.com/jfsantos/SRMRpy.git
#   Cloning https://github.com/jfsantos/SRMRpy.git to /tmp/pip-req-build-8j1bhxfd
#   Running command git clone --filter=blob:none --quiet https://github.com/jfsantos/SRMRpy.git /tmp/pip-req-build-8j1bhxfd
#   Resolved https://github.com/jfsantos/SRMRpy.git to commit fee009779cef96bed34db3a7e31d10f3ad1ea133
#   Preparing metadata (setup.py) ... done
# Collecting Gammatone@ https://github.com/detly/gammatone/archive/master.zip#egg=Gammatone (from SRMRpy==1.0)
#   Using cached https://github.com/detly/gammatone/archive/master.zip
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from SRMRpy==1.0) (2.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from SRMRpy==1.0) (1.15.3)
# Requirement already satisfied: nose in /usr/local/lib/python3.11/dist-packages (from Gammatone@ https://github.com/detly/gammatone/archive/master.zip#egg=Gammatone->SRMRpy==1.0) (1.3.7)
# Requirement already satisfied: mock in /usr/local/lib/python3.11/dist-packages (from Gammatone@ https://github.com/detly/gammatone/archive/master.zip#egg=Gammatone->SRMRpy==1.0) (5.2.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from Gammatone@ https://github.com/detly/gammatone/archive/master.zip#egg=Gammatone->SRMRpy==1.0) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->Gammatone@ https://github.com/detly/gammatone/archive/master.zip#egg=Gammatone->SRMRpy==1.0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->Gammatone@ https://github.com/detly/gammatone/archive/master.zip#egg=Gammatone->SRMRpy==1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->Gammatone@ https://github.com/detly/gammatone/archive/master.zip#egg=Gammatone->SRMRpy==1.0) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->Gammatone@ https://github.com/detly/gammatone/archive/master.zip#egg=Gammatone->SRMRpy==1.0) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->Gammatone@ https://github.com/detly/gammatone/archive/master.zip#egg=Gammatone->SRMRpy==1.0) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->Gammatone@ https://github.com/detly/gammatone/archive/master.zip#egg=Gammatone->SRMRpy==1.0) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->Gammatone@ https://github.com/detly/gammatone/archive/master.zip#egg=Gammatone->SRMRpy==1.0) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->Gammatone@ https://github.com/detly/gammatone/archive/master.zip#egg=Gammatone->SRMRpy==1.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->Gammatone@ https://github.com/detly/gammatone/archive/master.zip#egg=Gammatone->SRMRpy==1.0) (1.17.0)
# Requirement already satisfied: frechet_audio_distance in /usr/local/lib/python3.11/dist-packages (0.3.1)
# Collecting numpy==1.23.4 (from frechet_audio_distance)
#   Using cached numpy-1.23.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from frechet_audio_distance) (2.6.0+cu124)
# Collecting scipy==1.10.1 (from frechet_audio_distance)
#   Using cached scipy-1.10.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (58 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from frechet_audio_distance) (4.67.1)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.11/dist-packages (from frechet_audio_distance) (0.13.1)
# Requirement already satisfied: resampy in /usr/local/lib/python3.11/dist-packages (from frechet_audio_distance) (0.4.3)
# Requirement already satisfied: torchlibrosa in /usr/local/lib/python3.11/dist-packages (from frechet_audio_distance) (0.1.0)
# Requirement already satisfied: laion-clap in /usr/local/lib/python3.11/dist-packages (from frechet_audio_distance) (1.1.5)
# Requirement already satisfied: transformers<=4.30.2 in /usr/local/lib/python3.11/dist-packages (from frechet_audio_distance) (4.30.2)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (from frechet_audio_distance) (2.6.0+cu124)
# Requirement already satisfied: encodec in /usr/local/lib/python3.11/dist-packages (from frechet_audio_distance) (0.1.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers<=4.30.2->frechet_audio_distance) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.11/dist-packages (from transformers<=4.30.2->frechet_audio_distance) (0.32.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers<=4.30.2->frechet_audio_distance) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers<=4.30.2->frechet_audio_distance) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<=4.30.2->frechet_audio_distance) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers<=4.30.2->frechet_audio_distance) (2.32.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.11/dist-packages (from transformers<=4.30.2->frechet_audio_distance) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from transformers<=4.30.2->frechet_audio_distance) (0.5.3)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from encodec->frechet_audio_distance) (0.8.1)
# Requirement already satisfied: librosa in /usr/local/lib/python3.11/dist-packages (from laion-clap->frechet_audio_distance) (0.11.0)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.11/dist-packages (from laion-clap->frechet_audio_distance) (6.3.1)
# Requirement already satisfied: braceexpand in /usr/local/lib/python3.11/dist-packages (from laion-clap->frechet_audio_distance) (0.1.7)
# Requirement already satisfied: webdataset in /usr/local/lib/python3.11/dist-packages (from laion-clap->frechet_audio_distance) (0.2.111)
# Requirement already satisfied: wget in /usr/local/lib/python3.11/dist-packages (from laion-clap->frechet_audio_distance) (3.2)
# Requirement already satisfied: wandb in /usr/local/lib/python3.11/dist-packages (from laion-clap->frechet_audio_distance) (0.19.11)
# Requirement already satisfied: llvmlite in /usr/local/lib/python3.11/dist-packages (from laion-clap->frechet_audio_distance) (0.43.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from laion-clap->frechet_audio_distance) (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from laion-clap->frechet_audio_distance) (2.2.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from laion-clap->frechet_audio_distance) (3.13.0)
# Requirement already satisfied: progressbar in /usr/local/lib/python3.11/dist-packages (from laion-clap->frechet_audio_distance) (2.5)
# Requirement already satisfied: numba>=0.53 in /usr/local/lib/python3.11/dist-packages (from resampy->frechet_audio_distance) (0.60.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile->frechet_audio_distance) (1.17.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->frechet_audio_distance) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->frechet_audio_distance) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->frechet_audio_distance) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->frechet_audio_distance) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->frechet_audio_distance) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->frechet_audio_distance) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->frechet_audio_distance) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->frechet_audio_distance) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch->frechet_audio_distance) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch->frechet_audio_distance) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch->frechet_audio_distance) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch->frechet_audio_distance) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch->frechet_audio_distance) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->frechet_audio_distance) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->frechet_audio_distance) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->frechet_audio_distance) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->frechet_audio_distance) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->frechet_audio_distance) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->frechet_audio_distance) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->frechet_audio_distance) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile->frechet_audio_distance) (2.22)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers<=4.30.2->frechet_audio_distance) (1.1.2)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/dist-packages (from librosa->laion-clap->frechet_audio_distance) (3.0.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa->laion-clap->frechet_audio_distance) (1.5.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from librosa->laion-clap->frechet_audio_distance) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.11/dist-packages (from librosa->laion-clap->frechet_audio_distance) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from librosa->laion-clap->frechet_audio_distance) (0.5.0.post1)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.11/dist-packages (from librosa->laion-clap->frechet_audio_distance) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa->laion-clap->frechet_audio_distance) (1.1.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->laion-clap->frechet_audio_distance) (3.6.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy->laion-clap->frechet_audio_distance) (0.2.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->frechet_audio_distance) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->laion-clap->frechet_audio_distance) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->laion-clap->frechet_audio_distance) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->laion-clap->frechet_audio_distance) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers<=4.30.2->frechet_audio_distance) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers<=4.30.2->frechet_audio_distance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers<=4.30.2->frechet_audio_distance) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers<=4.30.2->frechet_audio_distance) (2025.4.26)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.11/dist-packages (from wandb->laion-clap->frechet_audio_distance) (8.2.1)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from wandb->laion-clap->frechet_audio_distance) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb->laion-clap->frechet_audio_distance) (3.1.44)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from wandb->laion-clap->frechet_audio_distance) (4.3.8)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.11/dist-packages (from wandb->laion-clap->frechet_audio_distance) (5.29.5)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb->laion-clap->frechet_audio_distance) (5.9.5)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.11/dist-packages (from wandb->laion-clap->frechet_audio_distance) (2.11.5)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb->laion-clap->frechet_audio_distance) (2.29.1)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.11/dist-packages (from wandb->laion-clap->frechet_audio_distance) (1.3.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from wandb->laion-clap->frechet_audio_distance) (75.2.0)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from docker-pycreds>=0.4.0->wandb->laion-clap->frechet_audio_distance) (1.17.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb->laion-clap->frechet_audio_distance) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb->laion-clap->frechet_audio_distance) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb->laion-clap->frechet_audio_distance) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb->laion-clap->frechet_audio_distance) (0.4.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->laion-clap->frechet_audio_distance) (5.0.2)
# Using cached numpy-1.23.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
# Using cached scipy-1.10.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.1 MB)
# Installing collected packages: numpy, scipy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.0
#     Uninstalling numpy-2.3.0:
#       Successfully uninstalled numpy-2.3.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.15.3
#     Uninstalling scipy-1.15.3:
#       Successfully uninstalled scipy-1.15.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jax 0.6.1 requires numpy>=1.25, but you have numpy 1.23.4 which is incompatible.
# jax 0.6.1 requires scipy>=1.11.1, but you have scipy 1.10.1 which is incompatible.
# jaxlib 0.6.1 requires numpy>=1.25, but you have numpy 1.23.4 which is incompatible.
# jaxlib 0.6.1 requires scipy>=1.11.1, but you have scipy 1.10.1 which is incompatible.
# pymc 5.23.0 requires numpy>=1.25.0, but you have numpy 1.23.4 which is incompatible.
# albucore 0.0.24 requires numpy>=1.24.4, but you have numpy 1.23.4 which is incompatible.
# mizani 0.13.5 requires numpy>=1.23.5, but you have numpy 1.23.4 which is incompatible.
# xarray-einstats 0.9.0 requires numpy>=1.25, but you have numpy 1.23.4 which is incompatible.
# xarray-einstats 0.9.0 requires scipy>=1.11, but you have scipy 1.10.1 which is incompatible.
# cvxpy 1.6.5 requires scipy>=1.11.0, but you have scipy 1.10.1 which is incompatible.
# pandas-stubs 2.2.2.240909 requires numpy>=1.23.5, but you have numpy 1.23.4 which is incompatible.
# treescope 0.1.9 requires numpy>=1.25.2, but you have numpy 1.23.4 which is incompatible.
# imbalanced-learn 0.13.0 requires numpy<3,>=1.24.3, but you have numpy 1.23.4 which is incompatible.
# bigframes 2.5.0 requires numpy>=1.24.0, but you have numpy 1.23.4 which is incompatible.
# sentence-transformers 4.1.0 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.30.2 which is incompatible.
# opencv-python-headless 4.11.0.86 requires numpy>=1.23.5; python_version >= "3.11", but you have numpy 1.23.4 which is incompatible.
# opencv-contrib-python 4.11.0.86 requires numpy>=1.23.5; python_version >= "3.11", but you have numpy 1.23.4 which is incompatible.
# plotnine 0.14.5 requires numpy>=1.23.5, but you have numpy 1.23.4 which is incompatible.
# albumentations 2.0.8 requires numpy>=1.24.4, but you have numpy 1.23.4 which is incompatible.
# tensorflow 2.18.0 requires ml-dtypes<0.5.0,>=0.4.0, but you have ml-dtypes 0.5.1 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 1.23.4 which is incompatible.
# xarray 2025.3.1 requires numpy>=1.24, but you have numpy 1.23.4 which is incompatible.
# blosc2 3.3.4 requires numpy>=1.26, but you have numpy 1.23.4 which is incompatible.
# opencv-python 4.11.0.86 requires numpy>=1.23.5; python_version >= "3.11", but you have numpy 1.23.4 which is incompatible.
# scikit-image 0.25.2 requires numpy>=1.24, but you have numpy 1.23.4 which is incompatible.
# scikit-image 0.25.2 requires scipy>=1.11.4, but you have scipy 1.10.1 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.23.4 which is incompatible.
# db-dtypes 1.4.3 requires numpy>=1.24.0, but you have numpy 1.23.4 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.10.1 which is incompatible.
# chex 0.1.89 requires numpy>=1.24.1, but you have numpy 1.23.4 which is incompatible.
# Successfully installed numpy-1.23.4 scipy-1.10.1
# Requirement already satisfied: librosa in /usr/local/lib/python3.11/dist-packages (0.11.0)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.11/dist-packages (0.13.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.10.1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/dist-packages (from librosa) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.60.0)
# Requirement already satisfied: numpy>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.23.4)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.5.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: typing_extensions>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (4.14.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile) (2.22)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from lazy_loader>=0.1->librosa) (24.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa) (4.3.8)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa) (2.32.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.0->librosa) (3.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2025.4.26)
# Requirement already satisfied: mir_eval in /usr/local/lib/python3.11/dist-packages (0.8.2)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.11/dist-packages (from mir_eval) (1.23.4)
# Requirement already satisfied: scipy>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from mir_eval) (1.10.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from mir_eval) (4.4.2)

# %% [markdown]
# This cell:
#
# Strips out Jupyter’s own command-line flags (sys.argv = sys.argv[:1]) so that any argparse calls in imported libraries don’t crash.
#
# Monkeys-patches NumPy so that np.dtypes points at the real numpy.core.numerictypes module, satisfying FAD’s expectation.
#
# Imports all of the functions and classes we’ll use:
#
# pesq (and its NoUtterancesError)
#
# srmr
#
# FrechetAudioDistance
#
# mir_eval.separation.bss_eval_sources

# %%
# ─── Cell 2: Monkey-patch & Imports ───
import sys
sys.argv = sys.argv[:1]  # drop extra Jupyter flags

import numpy as np
import numpy.core.numerictypes as _numerictypes
np.dtypes = _numerictypes  # shim for frechet_audio_distance

import librosa
import soundfile as sf

from pesq import pesq, NoUtterancesError
from srmrpy import srmr
from frechet_audio_distance import FrechetAudioDistance

import mir_eval  # for SDR
# Out:
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/jaxlib/plugin_support.py:71: RuntimeWarning: JAX plugin jax_cuda12_plugin version 0.5.1 is installed, but it is not compatible with the installed jaxlib version 0.6.1, so it will not be used.
#   warnings.warn(

# %% [markdown]
# This cell loads your two audio files and prepares them for analysis:
#
# Reads the AI-generated and AI-enhanced WAVs from the Colab file system.
#
# Converts any stereo to mono by averaging channels.
#
# Resamples both signals to 16 kHz, which is required for PESQ (wideband), SRMR, and the VGGish embeddings in FAD.
#
# Prints out the final sample rate and array shapes so you can sanity-check that everything loaded correctly.

# %%
# ─── Cell 3: Load & Preprocess Audio ───
import os

# Update these to match your Colab tree:
gen_path = '/content/Generated Audio/Kocking-door.wav'
enh_path = '/content/Enhanced Audio/knocking-door-1.wav'

assert os.path.exists(gen_path), f"{gen_path} not found"
assert os.path.exists(enh_path), f"{enh_path} not found"

gen, sr_gen = sf.read(gen_path)
enh, sr_enh = sf.read(enh_path)

# to mono
if gen.ndim > 1: gen = gen.mean(axis=1)
if enh.ndim > 1: enh = enh.mean(axis=1)

# resample to 16 kHz
target_sr = 16000
if sr_gen != target_sr:
    gen = librosa.resample(gen, orig_sr=sr_gen, target_sr=target_sr)
if sr_enh != target_sr:
    enh = librosa.resample(enh, orig_sr=sr_enh, target_sr=target_sr)

fs = target_sr
print(f"✔ Loaded & resampled to {fs} Hz mono. Shapes: gen={gen.shape}, enh={enh.shape}")
# Out:
# ✔ Loaded & resampled to 16000 Hz mono. Shapes: gen=(145868,), enh=(145868,)

# %% [markdown]
# This cell computes PESQ (wideband, ITU-T P.862.2) to evaluate speech quality:
#
# Wraps the call in a try/except to catch NoUtterancesError.
#
# If there’s no detectable speech (e.g. door knocks), it prints a warning instead of crashing.

# %%
# ─── Cell 4: Compute PESQ (P.862.2 wideband) with safe‐guard ───
try:
    pesq_score = pesq(fs, gen, enh, 'wb')
    print(f"PESQ (wideband) gen→enh: {pesq_score:.3f}")
except NoUtterancesError:
    print("⚠️ PESQ not applicable: no speech detected in these signals.")
# Out:
# ⚠️ PESQ not applicable: no speech detected in these signals.

# %% [markdown]
# This cell computes the raw SRMR (speech-to-reverberation modulation energy ratio) non-intrusively:
#
# Uses norm=False so that it returns a single meaningful float even for non-speech SFX.
#
# Prints the raw SRMR value, which reflects how “speech-like” the modulation structure is (higher = cleaner/less reverberant).

# %%
# ─── Cell 5: Compute SRMR ───
import numpy as np

srmr_out = srmr(
    enh,           # “degraded” / enhanced signal
    fs,
    n_cochlear_filters=23,
    low_freq=125,
    min_cf=4, max_cf=128,
    fast=True,
    norm=True
)

# Unpack if tuple
if isinstance(srmr_out, tuple):
    raw_srmr, norm_srmr = srmr_out
    # norm_srmr may be an array of per-band values → average to get a single score
    norm_scalar = norm_srmr.mean() if isinstance(norm_srmr, np.ndarray) else norm_srmr
    print(f"SRMR (raw)       : {raw_srmr:.3f}")
    print(f"SRMR (normalized): {norm_scalar:.3f}")
else:
    # single float return
    print(f"SRMR: {srmr_out:.3f}")
# Out:
# SRMR (raw)       : 2.548
# SRMR (normalized): 0.000

# %% [markdown]
# This cell computes the Fréchet Audio Distance (FAD) over your two folders of clips:
#
# Points gen_dir and enh_dir at the folders containing your generated vs. enhanced WAVs.
#
# Instantiates FrechetAudioDistance with the VGGish embedding model.
#
# Calls .score(...) to compare embedding distributions and prints out the resulting distance (lower = more similar).
#
# Make sure you’ve already removed any non-audio subfolders (e.g. .ipynb_checkpoints) so FAD only sees real clips

# %%
# ─── Cell 6a: Clean up hidden Jupyter checkpoints ───
# !find "/content/Generated Audio" -type d -name ".ipynb_checkpoints" -exec rm -rf {} +
# !find "/content/Enhanced Audio"  -type d -name ".ipynb_checkpoints" -exec rm -rf {} +

# %%
# ─── Cell 6b: Fréchet Audio Distance (FAD) ───
gen_dir = '/content/Generated Audio/'
enh_dir = '/content/Enhanced Audio/'

fad = FrechetAudioDistance(
    model_name="vggish",
    sample_rate=fs,
    use_pca=False,
    use_activation=False,
    verbose=False
)

fad_score = fad.score(gen_dir, enh_dir, dtype="float32")
print(f"FAD (gen vs enh): {fad_score:.3f}")
# Out:
# Using cache found in /root/.cache/torch/hub/harritaylor_torchvggish_master
# FAD (gen vs enh): -0.000

# %% [markdown]
# This cell computes two simple energy-based metrics:
#
# SNR:
#
# Defines “noise” as the difference between your generated and enhanced signals.
#
# Calculates 10·log10(signal_power / noise_power).
#
# Prints “∞ dB” if the two signals are identical (zero noise).
#
# SDR:
#
# Uses mir_eval.separation.bss_eval_sources to compute the signal-to-distortion ratio.
#
# Prints “∞ dB” when the SDR is extremely large or infinite (identical inputs).
#
# This gives you classic, interpretable scores alongside PESQ, SRMR, and FAD.

# %%
# ─── Cell 7: Simple SNR & SDR (cleaned up) ───
import numpy as np
import warnings
# ignore the FutureWarning from mir_eval
warnings.filterwarnings("ignore", category=FutureWarning)

from mir_eval.separation import bss_eval_sources

# crop to equal length
min_len = min(len(gen), len(enh))
gen_c, enh_c = gen[:min_len], enh[:min_len]

# SNR
noise = gen_c - enh_c
signal_power = np.sum(gen_c**2)
noise_power  = np.sum(noise**2)
if noise_power == 0:
    snr_str = "∞"
else:
    snr_val = 10 * np.log10(signal_power / noise_power)
    snr_str = f"{snr_val:.2f}"
print(f"SNR: {snr_str} dB")

# SDR via mir_eval
sdr, sir, sar, _ = bss_eval_sources(
    np.vstack([gen_c]),
    np.vstack([enh_c])
)
sdr_val = sdr[0]
# treat anything above 100 dB as infinite for clarity
if np.isinf(sdr_val) or sdr_val > 100:
    sdr_str = "∞"
else:
    sdr_str = f"{sdr_val:.2f}"
print(f"SDR: {sdr_str} dB")
# Out:
# SNR: ∞ dB
# SDR: ∞ dB
